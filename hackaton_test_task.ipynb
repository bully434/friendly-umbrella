# %% [markdown]
# SOME CODE WILL BE SITUATED JUST OVER THERE BITZHCHWHW

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 25, 15

# %%
data_df = pd.read_csv("data.csv", parse_dates = ["Start Time","End Time"], date_parser=pd.to_datetime)
# Out:
# c:\users\romutchio\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for column in data_df:
    print(column, ':', data_df[column].dtype)
# Out:
# Trip ID : int64
# Duration : int64
# Start Time : datetime64[ns]
# End Time : datetime64[ns]
# Starting Station ID : float64
# Starting Station Latitude : float64
# Starting Station Longitude : float64
# Ending Station ID : float64
# Ending Station Latitude : float64
# Ending Station Longitude : float64
# Bike ID : float64
# Plan Duration : float64
# Trip Route Category : object
# Passholder Type : object
# Starting Lat-Long : object
# Ending Lat-Long : object

# %%
data_df.head(30)
# Out:
#     Trip ID  Duration          Start Time            End Time  \
# 0   1912818       180 2016-07-07 04:17:00 2016-07-07 04:20:00
# 1   1919661      1980 2016-07-07 06:00:00 2016-07-07 06:33:00
# 2   1933383       300 2016-07-07 10:32:00 2016-07-07 10:37:00
# 3   1944197     10860 2016-07-07 10:37:00 2016-07-07 13:38:00
# 4   1940317       420 2016-07-07 12:51:00 2016-07-07 12:58:00
# 5   1944075       780 2016-07-07 12:51:00 2016-07-07 13:04:00
# 6   1944073       600 2016-07-07 12:54:00 2016-07-07 13:04:00
# 7   1944067       600 2016-07-07 12:59:00 2016-07-07 13:09:00
# 8   1944062      2880 2016-07-07 13:01:00 2016-07-07 13:49:00
# 9   1944063       960 2016-07-07 13:01:00 2016-07-07 13:17:00
# 10  1944061       960 2016-07-07 13:02:00 2016-07-07 13:18:00
# 11  1944059       720 2016-07-07 13:03:00 2016-07-07 13:15:00
# 12  1944058       360 2016-07-07 13:03:00 2016-07-07 13:09:00
# 13  1944054       120 2016-07-07 13:04:00 2016-07-07 13:06:00
# ...

# %%
for column_name in data_df.columns:
    column = data_df[column_name]
    nans = column[pd.isnull(column)]
    print(column_name, len(nans))
# Out:
# Trip ID 0
# Duration 0
# Start Time 0
# End Time 0
# Starting Station ID 19
# Starting Station Latitude 48
# Starting Station Longitude 48
# Ending Station ID 96
# Ending Station Latitude 1051
# Ending Station Longitude 1051
# Bike ID 10
# Plan Duration 766
# Trip Route Category 0
# Passholder Type 0
# Starting Lat-Long 33805
# Ending Lat-Long 1051

# %%
types = np.unique(data_df.agg('Passholder Type'))

print(min(((typ, len(data_df[data_df['Passholder Type']==typ])) for typ in types), key=lambda e: e[1]))
# Out:
# ('Staff Annual', 382)

# %%
data_df['Path lenght'] = data_df['End Time'] - data_df['Start Time']

# %%
sort_data = data_df['Path lenght'].sort_values()
print("min time:",sort_data.head(1))
print("max time:",sort_data.tail(1))
print("mean time:", data_df['Path lenght'].mean())
# Out:
# min time: 65687   00:01:00
# Name: Path lenght, dtype: timedelta64[ns]
# max time: 23475   5 days 16:28:00
# Name: Path lenght, dtype: timedelta64[ns]
# mean time: 0 days 00:28:11.324276

# %%
len(data_df[data_df['Starting Station ID'] == 3000.0])
# Out:
# c:\program files (x86)\python37-32\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0

# %%
len(data_df[pd.isnull(data_df["Starting Station ID"])])
# Out:
# 19

# %%
19+29
# Out:
# 48

# %%
unique_stations_count = data_df["Starting Station ID"].unique().shape
print("Сколько всего уникальных станций? (количество всех станций без повторений) - {}".format(unique_stations_count[0]))
# Out:
# Сколько всего уникальных станций? (количество всех станций без повторений) - 68

# %%
unique_bikes_count = data_df["Bike ID"].unique().shape
print("Сколько всего велосипедов? (количество уникальных) - {}".format(unique_stations_count[0]))
# Out:
# Сколько всего велосипедов? (количество уникальных) - 764

# %%
most_popular_bikes = data_df["Bike ID"].value_counts()
print("Какие велосипеды самые популярные? (назовите их Bike ID) {}".format(", ".join(str(x) for x in most_popular_bikes.index)))
# Out:
# Какие велосипеды самые популярные? (назовите их Bike ID) 4727.0, 6583.0, 5839.0, 6328.0, 6162.0, 6618.0, 6075.0, 6435.0, 6254.0, 6635.0, 5871.0, 6527.0, 6717.0, 5879.0, 6424.0, 6089.0, 6146.0, 6209.0, 6277.0, 6063.0, 6249.0, 6536.0, 6403.0, 6677.0, 6446.0, 5931.0, 5986.0, 6389.0, 6019.0, 5924.0, 6273.0, 6115.0, 6405.0, 6647.0, 5900.0, 6286.0, 6141.0, 5932.0, 6398.0, 6503.0, 6302.0, 5966.0, 6216.0, 6313.0, 5860.0, 6644.0, 5842.0, 6344.0, 6500.0, 6223.0, 5851.0, 6178.0, 5739.0, 6371.0, 6413.0, 6608.0, 6059.0, 6393.0, 5890.0, 5838.0, 6520.0, 6158.0, 6061.0, 6299.0, 6266.0, 6511.0, 6373.0, 6580.0, 6447.0, 5832.0, 5998.0, 6599.0, 6474.0, 6353.0, 5770.0, 6182.0, 6603.0, 6675.0, 6267.0, 6556.0, 6728.0, 5755.0, 6102.0, 6144.0, 5977.0, 6606.0, 6385.0, 6487.0, 6621.0, 6274.0, 6692.0, 6100.0, 5988.0, 6262.0, 5867.0, 6106.0, 6310.0, 5929.0, 6130.0, 6234.0, 5967.0, 6676.0, 6440.0, 6307.0, 5817.0, 6303.0, 6076.0, 6081.0, 6291.0, 5899.0, 6423.0, 6120.0, 6155.0, 6179.0, 5951.0, 6185.0, 6434.0, 5754.
# ...

# %%
most_popular_starting_stations = data_df["Starting Station ID"].value_counts()
most_popular_ending_stations = data_df["Ending Station ID"].value_counts()
print("Самые популярные начальные станции {}".format(", ".join(str(x) for x in most_popular_bikes.head(10).index)))
print("Самые популярные конечные станции {}".format(", ".join(str(x) for x in most_popular_ending_stations.head(10).index)))
# Out:
# Самые популярные начальные станции 3069.0, 3030.0, 3005.0, 3064.0, 3031.0, 3014.0, 3042.0, 3082.0, 3022.0, 3067.0
# Самые популярные конечные станции 3005.0, 3031.0, 3014.0, 3042.0, 3069.0, 3082.0, 3064.0, 3022.0, 3030.0, 3063.0
